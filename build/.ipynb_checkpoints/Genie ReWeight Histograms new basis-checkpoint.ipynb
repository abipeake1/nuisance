# %%
import ROOT 
import numpy as np
import matplotlib.pyplot as plt
# %jsroot on
# Out:
# Welcome to JupyROOT 6.28/00

# %%
#myFile = ROOT.TFile.Open("/Users/abigailpeake/software/nuisance/build/newtune_resultsfile_1000.root")
#myFile = ROOT.TFile.Open("/Users/abigailpeake/software/nuisance/build/10e5events_10GeV_newbasis_rebinned_310723_addedminusb.root")
#myFile = ROOT.TFile.Open("/Users/abigailpeake/software/nuisance/build/10GeVonly_newtune_resultsfile_10e5.root")

#myFile = ROOT.TFile.Open("/Users/abigailpeake/software/nuisance/build/10e5events_10GeV_newbasis_rebinned_020823.root")




#myFile = ROOT.TFile.Open("/Users/abigailpeake/software/nuisance/build/10e3events_10GeV_080823_uncommented.root")
#myFile = ROOT.TFile.Open("/Users/abigailpeake/software/nuisance/build/10e3events_10GeV_110823_uncommented.root")

myFilehists = ROOT.TFile.Open("/Users/abigailpeake/software/nuisance/build/10e5events_10GeV_test_new_2508_new_lowerbins.root")


c = ROOT.TCanvas()

# %%
histo_a1 = myFilehists.Q2histrwa1
histo_a2 = myFilehists.Q2histrwa2
histo_a3 = myFilehists.Q2histrwa3
histo_a4 = myFilehists.Q2histrwa4

histo_altogether = myFilehists.Q2histrwaltogether  #Varying [a1,a2,a3,a4] simultaneously by 1sigma

histo_acv = myFilehists.Q2histrw #[a1,a2,a3,a4] at their Central Values
histo_acv_new = myFilehists.Q2histzex_cv
histo_a1_minus = myFilehists.Q2histrwa1minus
histo_a2_minus = myFilehists.Q2histrwa2minus
histo_a3_minus = myFilehists.Q2histrwa3minus
histo_a4_minus = myFilehists.Q2histrwa4minus

histo_altogether_minus = myFilehists.Q2histrwaltogetherminus

# %%
histo_stats_newbasis = myFilehists.mystatshisto
#histo_stats_newbasis.Rebin(25)
histo_b1 = myFilehists.Q2hist_myccqereweighter_rw_b1
histo_b2 = myFilehists.Q2hist_myccqereweighter_rw_b2
histo_b3 = myFilehists.Q2hist_myccqereweighter_rw_b3
histo_b4 = myFilehists.Q2hist_myccqereweighter_rw_b4


histo_b1_minus = myFilehists.Q2hist_myccqereweighter_rw_b1_minus
histo_b2_minus = myFilehists.Q2hist_myccqereweighter_rw_b2__minus
histo_b3_minus = myFilehists.Q2hist_myccqereweighter_rw_b3_minus
histo_b4_minus = myFilehists.Q2hist_myccqereweighter_rw_b4_minus



testing = myFilehists.Q2hist_myccqereweighter_rw_b1_b2

# %%
hist_list = [myFilehists.Q2hist_myccqereweighter_rw_b1_b2, myFilehists.Q2hist_myccqereweighter_rw_b1_b2_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b1_3, myFilehists.Q2hist_myccqereweighter_rw_b1_b3_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b1_b34, myFilehists.Q2hist_myccqereweighter_rw_b1_b4_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b2_b3, myFilehists.Q2hist_myccqereweighter_rw_b2_b3_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b2_b4, myFilehists.Q2hist_myccqereweighter_rw_b2_b4_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b3_b4, myFilehists.Q2hist_myccqereweighter_rw_b2_b4_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b1_b2_b3, myFilehists.Q2hist_myccqereweighter_rw_b1_b2_b3_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b1_b2_b4, myFilehists.Q2hist_myccqereweighter_rw_b1_b2_b4_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b2_b3_b4, myFilehists.Q2hist_myccqereweighter_rw_b2_b3_b4_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b1_b3_b4, myFilehists.Q2hist_myccqereweighter_rw_b1_b3_b4_minus,
             myFilehists.Q2hist_myccqereweighter_rw_b1_b2_b3_b4, myFilehists.Q2hist_myccqereweighter_rw_b1_b2_b3_b4_minus]

# %%
len(hist_list)
# Out:
# 22

# %%
canvas_newbasis=ROOT.TCanvas()
x = histo_stats_newbasis
#y = histo_acv
ynew = histo_acv_new
#x.Scale(1. / x.Integral(), "width");
#y.Scale(1. / y.Integral(), "width");

#x.Draw('CHIST')
#y.Draw('CHIST')
x.Draw('CHIST SAME')
#ynew.Draw('CHIST SAME')
canvas_newbasis.Update()
canvas_newbasis.Draw()
# Out:
# <div id="root_plot_1693342114675"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1693342114675(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.875000065192584,"fY1":-2131.95869670296,"fX2":7.87500006519259,"fY2":25183.6752663275,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":79.5428559575761,"fYtoAbsPixelk":435.160908495698,"fYtoPixelk":435.160908495698,"fYtoPixel":-0.0172794818029417,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.875000065192584,"fPixeltoXk":-0.875000065192584,"fPixeltoX":0.0125718392677948,"fAbsPixeltoYk":25183.6752663275,"fPixeltoYk":-2131.95869670296,"fPixeltoY":-57.8721058538781,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":599.604862413962,"fUxmax":7,"fUymax":22452.1117072106,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":599.604862413962,"fX2":7,"fY2":22452.1117072106,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":8,"fName":"mystatshisto","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":27,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"Q2","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":25,"fXmin":0,"fXmax":7,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"count","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":35,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":{"$arr":"Float64","len":27,"p":1,"v":[926523.081043902,6212807.72876656,10340545.5355244,15081655.0576096,20501320.7102309,24285174.8880189,29712233.4491828,29452604.4206112,33765521.5913465,32698522.6045382,29900496.56941,28957956.9049204,30299608.4737043,25370735.7258052,29324899.8480645,24930845.4116884,19049869.257455,22636442.1567107,22494330.3203861,18583436.1228495,17337221.6446034,12213546.1212306,13714500.8215194,13714629.8717014,9113069.14232926,7768790.16623766]},"fOption":"","fFunctions":{"_typename":"TList","name":"TList"," ...

# %%
canvas_newbasis1=ROOT.TCanvas()
#x = histo_stats_newbasis
#y = histo_acv
ynew = histo_acv_new
#x.Scale(1. / x.Integral(), "width");
#y.Scale(1. / y.Integral(), "width");
ynew.SetStats(1)
#x.Draw('CHIST')
#y.Draw('CHIST')
#x.Draw('CHIST SAME')
ynew.Draw('CHIST')
canvas_newbasis1.Update()
canvas_newbasis1.Draw()
# Out:
# <div id="root_plot_1693342128025"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1693342128025(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.875000065192584,"fY1":-2817.15020989404,"fX2":7.87500006519259,"fY2":25354.350209894,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":79.5428559575761,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.0167545211638234,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.875000065192584,"fPixeltoXk":-0.875000065192584,"fPixeltoX":0.0125718392677948,"fAbsPixeltoYk":25354.350209894,"fPixeltoYk":-2817.15020989404,"fPixeltoY":-59.6853822453137,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":7,"fUymax":22537.2,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":7,"fY2":22537.2,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":8,"fName":"Q2histzex_cv","fTitle":"q2","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":37,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"Q^{2}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":35,"fXmin":0,"fXmax":7,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"Count","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":100000,"fTsumw":99873,"fTsumw2":99873,"fTsumwx":70976.5457050001,"fTsumwx2":104763.708910125,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":5.95000017732382,"fY1":19015.762783357,"fX2":7.70000022947789,"fY2":23523.2027497739,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTextAngle":0,"fTextSize":0,"fTextAlign":12,"fText ...

# %%
canvas_r=ROOT.TCanvas()
r =myFilehists.hist_throw_99

ynew.Draw('CHIST')
r.Draw('SAME')
canvas_r.Update()
canvas_r.Draw()
# Out:
# <div id="root_plot_1693342130626"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1693342130626(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.875000065192584,"fY1":-2817.15020989404,"fX2":7.87500006519259,"fY2":25354.350209894,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":79.5428559575761,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.0167545211638234,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.875000065192584,"fPixeltoXk":-0.875000065192584,"fPixeltoX":0.0125718392677948,"fAbsPixeltoYk":25354.350209894,"fPixeltoYk":-2817.15020989404,"fPixeltoY":-59.6853822453137,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":7,"fUymax":22537.2,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":7,"fY2":22537.2,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":8,"fName":"Q2histzex_cv","fTitle":"q2","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":37,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"Q^{2}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":35,"fXmin":0,"fXmax":7,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"Count","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":100000,"fTsumw":99873,"fTsumw2":99873,"fTsumwx":70976.5457050001,"fTsumwx2":104763.708910125,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":5.95000017732382,"fY1":19015.762783357,"fX2":7.70000022947789,"fY2":23523.2027497739,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTextAngle":0,"fTextSize":0,"fTextAlign":12,"fText ...

# %%
# Extract mean and std of each bin in each histogram
mean_nb = []
sd_nb = []

mean_a1 = []
sd_a1 = []

mean_a2 = []
sd_a2 = []

mean_a3 = []
sd_a3 = []

mean_a4 = []
sd_a4 = []

mean_acv= []
std_acv =[]


mean_altogether = []
sd_altogether = []
sd_altogether_minus=[]

Q2 = []
binedge = []

mean_a1_minus = []
mean_a2_minus = []
mean_a3_minus = []
mean_a4_minus = []
mean_altogether_minus = []

mean_altogether_nb = []
mean_altogether_nb_minus = []

mean_b1 = []
mean_b2 = []
mean_b3= []
mean_b4= []



mean_b1_minus = []
mean_b2_minus = []
mean_b3_minus = []
mean_b4_minus = []

std_mystatshisto_minus = []
std_mystatshisto = []

Q2_histo = []


#histo_a1.Rebin(20)
nbins = 35
for i in range (0,nbins):
    
    
    std_mystatshisto.append(histo_stats_newbasis.GetBinErrorUp(i))
    std_mystatshisto_minus.append(histo_stats_newbasis.GetBinErrorLow(i))
    
    b1 = histo_b1.GetBinContent(i)
    mean_b1.append(b1)
    
    b2 = histo_b2.GetBinContent(i)
    mean_b2.append(b2)
    
    b3 = histo_b3.GetBinContent(i)
    mean_b3.append(b3)
    
    b4 = histo_b4.GetBinContent(i)
    mean_b4.append(b4)
    
    #print("in bin {}".format(i))
    a1 = histo_a1.GetBinContent(i)
    mean_a1.append(a1)
     
    a2 = histo_a2.GetBinContent(i)
    mean_a2.append(a2)
    
    a3 = histo_a3.GetBinContent(i)
    mean_a3.append(a3)
    
    a4 = histo_a4.GetBinContent(i)
    mean_a4.append(a4)
     
    acv = histo_acv.GetBinContent(i)
    mean_acv.append(acv)
    
    
    std_acv.append(histo_acv.GetBinError(i))
    
    altogether = histo_altogether.GetBinContent(i)
    mean_altogether.append(altogether)
    sd_altogether.append(histo_altogether.GetBinError(i))
    
    
    a1_minus = histo_a1_minus.GetBinContent(i)
    mean_a1_minus.append(a1_minus)
    
    
    a2_minus = histo_a2_minus.GetBinContent(i)
    mean_a2_minus.append(a2_minus)
    
    a3_minus = histo_a3_minus.GetBinContent(i)
    mean_a3_minus.append(a3_minus)
    
    a4_minus = histo_a4_minus.GetBinContent(i)
    mean_a4_minus.append(a4_minus)
    
    altogether_minus = histo_altogether_minus.GetBinContent(i)
    mean_altogether_minus.append(altogether_minus)
    sd_altogether_minus.append(histo_altogether_minus.GetBinError(i))
    Q2_histo.append( histo_altogether_minus.GetBinCenter(i))
    
    
    center = histo_altogether.GetBinCenter(i)
    edge = histo_altogether.GetBinLowEdge(i)
    Q2.append(center)
    binedge.append(edge)
    
    
    bplus = histo_stats_newbasis.GetBinContent(i)
    mean_altogether_nb.append(bplus)
    
    bminus = histo_stats_newbasis.GetBinContent(i)
    mean_altogether_nb_minus.append(bminus)
    
    b1_minus= histo_b1_minus.GetBinContent(i)
    mean_b1_minus.append(b1_minus)
    
    b2_minus= histo_b2_minus.GetBinContent(i)
    mean_b2_minus.append(b2_minus)
    
    b3_minus= histo_b3_minus.GetBinContent(i)
    mean_b3_minus.append(b3_minus)
    
    b4_minus= histo_b4_minus.GetBinContent(i)
    mean_b4_minus.append(b4_minus)
    
    
#mean_a1 = histo_a1.GetBinContent(9)
print(mean_a1)
print(mean_a2)
print(mean_a3)
print(mean_a4)

print(mean_acv)

print(mean_altogether_nb)


print(mean_b1)
print(mean_b2)
print(mean_b3)
print(mean_b4)


print(np.shape(mean_acv))
print(np.shape(mean_b1))
print(np.shape(mean_b1_minus))
print(np.shape(Q2))
print(np.shape(bplus))


print(mean_altogether_nb)
# Out:
# [0.0, 20951.659939820576, 18848.35129610671, 13517.702739511416, 9308.96320362492, 6319.419165452727, 4182.831584641408, 2903.657873971597, 1905.8143958749804, 1391.5912124120935, 982.4945793912502, 694.6788651848069, 548.2497315123042, 455.4168714094884, 344.6144642849046, 320.93155393668644, 258.1976515284235, 209.83734509471742, 208.52076895450026, 194.5490960702791, 168.8327972168054, 154.29760673101484, 126.55630022544516, 128.20374960338256, 125.74826112502804, 104.27489034405463, 93.24200487981476, 91.88293360117808, 106.27664611171878, 71.45772710020289, 72.64280244452095, 72.95799725308625, 66.82980488092508, 76.00287116265265, 67.74331355408147]
# [0.0, 20977.6345327523, 19751.957460942027, 15088.963884956023, 11124.011422710955, 8099.291320822432, 5732.661588919311, 4242.198542784615, 2940.0256579312672, 2253.0035341333587, 1642.2837658143396, 1188.8379277127672, 932.5121789085929, 764.1614012490495, 567.0688106084073, 506.3562909324161, 391.69094998421684, 296.8620901668528, 277.11177112379073, 242.27983134037737, 195.55398892857013, 166.89866937736525, 126.69361724869088, 120.68263528145562, 110.804022655155, 81.80519215185383, 69.59100552416126, 65.77244262487118, 67.88653778815383, 43.59526115480848, 41.94316737339536, 44.46767306358602, 33.47279637365914, 36.07158867921652, 29.70131798845847]
# [0.0, 21508.76195701601, 20723.19306542697, 16012.465912042066, 12040.835177586354, 9038.01457989493, 6649.918242313392, 5156.1188782555955, 3762.798248031004, 3054.9161707202834, 2365.443490284924, 1828.5227950374458, 1520.6735240169041, 1329.6071892395942, 1057.3360145841907, 1008.0109812950001, 835.7184411418657, 669.8754943124416, 669.7337236151151, 622.3483243863246, 531.5918759630257, 483.7239792254985, 386.4512284431689, 391.09043138894464, 376.56590202015104, 292.2699328223714, 261.81365496344335, 260.52428830024405, 278.47872303593834, 188.00526189238218, 190.8345465265212, 212.86538102557932, 163.71517773979994, 183.40807119311947, 156.61609202105274]
# [0.0, 22357.494494195736, 22058.475845088902, 17187.058149703338, 12921.759945995209, 9644.846105625582, 7031.124525352175, 5386.029989454834, 3874.5422066125043, 3095.6294979106638, 2355.0097871141024, 1786.3476995680824, 1458.7522025613514, 1250.9013228142467, 975.1065506170496, 911.5992926828379, 741.350850945725, 584.0926345908956, 572.8895749677264, 523.4659220607642, 439.99709841011344, 393.67855116287075, 310.08393331371093, 309.05221761675335, 293.8545667575475, 224.9282885758534, 199.0244978290943, 195.64193908187588, 206.9283169977138, 138.20549390933405, 138.59402324479652, 153.35993868346762, 116.73968372480931, 129.69744229914627, 109.72537967782579]
# [0.0, 21234.341406458272, 19174.21221030852, 13891.63194244909, 9389.312701830066, 6115.632246355427, 3878.5306287173657, 2642.7510477276132, 1796.2272129050948, 1455.0404889568931, 1218.8953360151788, 1070.1722985089518, 1043.5399165181113, 1077.2989466078502, 1003.706675986234, 1115.8790603480156, 1056.283523553325, 960.2410631342918, 1077.8434651352072, 1103.0502384260242, 1029.9013516996563, 1016.2741910141852, 873.281730915183, 939.7854346705195, 955.8248015377573, 802.5430708509933, 747.7916481087633, 769.3063291306861, 877.7946151488361, 610.1636790357824, 640.3378118582424, 699.1758601153182, 592.6552312327673, 681.9570151515612, 605.9068571139518]
# (35,)
# (35,)
# (35,)
# (35,)
# ()
# [0.0, 21411.51614317266, 20578.54007122962, 15990.458635845582, 12126.53218383884, 9338.343406496291, 7246.396098529027, 6113.933833787554, 4974.957895970649, 4578.682012404028, 4045.582258605549, 3571.4631034624636, 3341.1437342354143, 3281.1961425675418, 2908.642024050213, 3058.526343720539, 2769.480147498041, 2394.919145337622, 2581.913347708298, 2553.9293955909125, 2308.213078313332, 2216.918447082186, 1854.6782924759477, 1957.6080697242621, 1953.2200179912554, 1590.6482567358044, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693]

# %% [markdown]
# Now let's calculate the ratios: Need to know $F_{A}(a_{i}+ \sigma) / F_{A}(a_{cv})$ so I can copmare to the results I had before using the Covariance matrix

# %%
a1_ratio = np.divide(mean_a1, mean_acv)
a2_ratio = np.divide(mean_a2, mean_acv)
a3_ratio = np.divide(mean_a3, mean_acv)
a4_ratio = np.divide(mean_a4, mean_acv)
a_altogether_ratio = np.divide(mean_altogether, mean_acv)

b1_ratio = np.divide(mean_b1, mean_acv)
b2_ratio = np.divide(mean_b2, mean_acv)
b3_ratio = np.divide(mean_b3, mean_acv)
b4_ratio = np.divide(mean_b4, mean_acv)

bratio = np.divide(mean_altogether_nb, mean_acv)
bratio_minus = np.divide(mean_altogether_nb_minus, mean_acv)

a1_ratio_minus = np.divide(mean_a1_minus, mean_acv)
a2_ratio_minus = np.divide(mean_a2_minus, mean_acv)
a3_ratio_minus = np.divide(mean_a3_minus, mean_acv)
a4_ratio_minus = np.divide(mean_a4_minus, mean_acv)

b1_ratio_minus = np.divide(mean_b1_minus, mean_acv)
b2_ratio_minus = np.divide(mean_b2_minus, mean_acv)
b3_ratio_minus = np.divide(mean_b3_minus, mean_acv)
b4_ratio_minus = np.divide(mean_b4_minus, mean_acv)

a_altogether_ratio_minus = np.divide(mean_altogether_minus, mean_acv)


print(a1_ratio)
print(a1_ratio_minus)

print(mean_a1_minus)
 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693, 1465.230186724693]
# [        nan  0.98866759  0.99333381  1.00810246  1.04191337  1.11142483
#   1.23157674  1.42163687  1.69203028  2.0623155   2.53907811  3.15016
#   3.8171155   4.65613273  5.67093542  6.80742696  8.13995079  9.45135724
#  11.16883826 12.90495629 14.75631386 17.02321946 19.13774577 21.7898781
#  24.19043179 27.16158078 30.2318548  32.96003814 32.26004875 51.82225511
#  55.81706374 55.82217546 72.58228258 69.092654   85.3596083 ]
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:1: RuntimeWarning: invalid value encountered in divide
#   a1_ratio = np.divide(mean_a1, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:2: RuntimeWarning: invalid value encountered in divide
#   a2_ratio = np.divide(mean_a2, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:3: RuntimeWarning: invalid value encountered in divide
#   a3_ratio = np.divide(mean_a3, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:4: RuntimeWarning: invalid value encountered in divide
#   a4_ratio = np.divide(mean_a4, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:5: RuntimeWarning: invalid value encountered in divide
#   a_altogether_ratio = np.divide(mean_altogether, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:7: RuntimeWarning: invalid value encountered in divide
#   b1_ratio = np.divide(mean_b1, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:8: RuntimeWarning: invalid value encountered in divide
#   b2_ratio = np.divide(mean_b2, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:9: RuntimeWarning: invalid value encountered in divide
#   b3_ratio = np.divide(mean_b3, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:10: RuntimeWarning: invalid value encountered in divide
#   b4_ratio = np.divide(mean_b4, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:12: RuntimeWarning: invalid value encountered in divide
#   bratio = np.divide(mean_altogether_nb, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:13: RuntimeWarning: invalid value encountered in divide
#   bratio_minus = np.divide(mean_altogether_nb_minus, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:15: RuntimeWarning: invalid value encountered in divide
#   a1_ratio_minus = np.divide(mean_a1_minus, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:16: RuntimeWarning: invalid value encountered in divide
#   a2_ratio_minus = np.divide(mean_a2_minus, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:17: RuntimeWarning: invalid value encountered in divide
#   a3_ratio_minus = np.divide(mean_a3_minus, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:18: RuntimeWarning: invalid value encountered in divide
#   a4_ratio_minus = np.divide(mean_a4_minus, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:20: RuntimeWarning: invalid value encountered in divide
#   b1_ratio_minus = np.divide(mean_b1_minus, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:21: RuntimeWarning: invalid value encountered in divide
#   b2_ratio_minus = np.divide(mean_b2_minus, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:22: RuntimeWarning: invalid value encountered in divide
#   b3_ratio_minus = np.divide(mean_b3_minus, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:23: RuntimeWarning: invalid value encountered in divide
#   b4_ratio_minus = np.divide(mean_b4_minus, mean_acv)
# /var/folders/9v/_33459qd6t56dm18fvb6tq9c0000gn/T/ipykernel_6619/1134459078.py:25: RuntimeWarning: invalid value encountered in divide
#   a_altogether_ratio_minus = np.divide(mean_altogether_minus, mean_acv)

# %%
#Let's get rid of the 'nan'
a1_ratio_new = np.nan_to_num(a1_ratio, 0)
a2_ratio_new = np.nan_to_num(a2_ratio, 0)
a3_ratio_new = np.nan_to_num(a3_ratio, 0)
a4_ratio_new = np.nan_to_num(a4_ratio, 0)


a1_ratio_minus_new = np.nan_to_num(a1_ratio_minus, 0)
a2_ratio_minus_new = np.nan_to_num(a2_ratio_minus, 0)
a3_ratio_minus_new = np.nan_to_num(a3_ratio_minus, 0)
a4_ratio_minus_new = np.nan_to_num(a4_ratio_minus, 0)

b1_ratio_new = np.nan_to_num(b1_ratio, 0)
b2_ratio_new = np.nan_to_num(b2_ratio, 0)
b3_ratio_new = np.nan_to_num(b3_ratio, 0)
b4_ratio_new = np.nan_to_num(b4_ratio, 0)


b1_ratio_minus_new = np.nan_to_num(b1_ratio_minus, 0)
b2_ratio_minus_new = np.nan_to_num(b2_ratio_minus, 0)
b3_ratio_minus_new = np.nan_to_num(b3_ratio_minus, 0)
b4_ratio_minus_new = np.nan_to_num(b4_ratio_minus, 0)





b_ratio_new = np.nan_to_num(bratio, 0)
b_ratio_minus_new = np.nan_to_num(bratio_minus, 0)


print(np.shape(Q2))

print(np.shape(a1_ratio_new))
# Out:
# (35,)
# (35,)

# %%
plt.plot(Q2, a1_ratio_new, label='a1 ratio', color='blue')
plt.plot(Q2, a2_ratio_new,label='a2 ratio',color='red')
plt.plot(Q2, a3_ratio_new,label='a3 ratio',color='green')
plt.plot(Q2, a4_ratio_new,label='a4 ratio', color='purple')

plt.plot(Q2, a1_ratio_minus_new, color='blue')
plt.plot(Q2, a2_ratio_minus_new,color='red')
plt.plot(Q2, a3_ratio_minus_new,color='green')
plt.plot(Q2, a4_ratio_minus_new,color='purple')


#plt.plot(Q2, b_ratio_new, color='pink', label='new basis')
#plt.plot(Q2, b_ratio_minus_new, color='pink')


#plt.semilogy()
plt.legend()
plt.xlim(0,7)

plt.xlabel('$Q^{2}$ (GeV)')
plt.ylabel('Ratio (no units)')
plt.show()

# %%
plt.plot(Q2, b1_ratio_new, label='b1 ratio', color='blue')
plt.plot(Q2, b2_ratio_new,label='b2 ratio',color='red')
plt.plot(Q2, b3_ratio_new,label='b3 ratio',color='green')
plt.plot(Q2, b4_ratio_new,label='b4 ratio', color='purple')

plt.plot(Q2, b1_ratio_minus_new, color='blue')
plt.plot(Q2, b2_ratio_minus_new,color='red')
plt.plot(Q2, b3_ratio_minus_new,color='green')
plt.plot(Q2, b4_ratio_minus_new,color='purple')


#plt.plot(Q2, b_ratio_new, color='pink', label='new basis')
#plt.plot(Q2, b_ratio_minus_new, color='pink')


#plt.semilogy()
plt.legend()
plt.xlim(0,7)

plt.xlabel('$Q^{2}$ (GeV)')
plt.ylabel('Ratio (no units)')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(12,6))

ax1.plot(Q2, a1_ratio_new, color='blue', label='$a_{1}$ ratio')
ax1.plot(Q2, a2_ratio_new,label='$a_{2}$ ratio',color='red')
ax1.plot(Q2, a3_ratio_new,label='$a_{3}$ ratio',color='green')
ax1.plot(Q2, a4_ratio_new,label='$a_{4}$ ratio', color='purple')
ax1.plot(Q2, a1_ratio_minus_new, color='blue')
ax1.plot(Q2, a2_ratio_minus_new,color='red')
ax1.plot(Q2, a3_ratio_minus_new,color='green')
ax1.plot(Q2, a4_ratio_minus_new,color='purple')
ax1.legend()
ax1.set_xlim(0,5)
ax1.set_xlabel('$Q^{2}$ (GeV)')
ax1.set_ylabel('Ratio (no units)')
ax1.set_ylim(0,10)


ax2.plot(Q2, b1_ratio_new, color='blue', label='$b_{1}$ ratio')
ax2.plot(Q2, b2_ratio_new,label='$b_{2}$ ratio',color='red')
ax2.plot(Q2, b3_ratio_new,label='$b_{3}$ ratio',color='green')
ax2.plot(Q2, b4_ratio_new,label='$b_{4}$ ratio', color='purple')
ax2.plot(Q2, b1_ratio_minus_new, color='blue')
ax2.plot(Q2, b2_ratio_minus_new,color='red')
ax2.plot(Q2, b3_ratio_minus_new,color='green')
ax2.plot(Q2, b4_ratio_minus_new,color='purple')
ax2.legend()
ax2.set_xlim(0,5)
ax2.set_xlabel('$Q^{2}$ (GeV)')

ax1.grid()
ax2.grid()

# %%
plt.plot(Q2,mean_altogether_nb,  label='Varying $b_{1},b_{2},b_{3},b_{4}$ together')
plt.plot(Q2, mean_b1, label='Varying $b_{1}$')
plt.plot(Q2, mean_b2, label='Varying $b_{2}$')
plt.plot(Q2, mean_b3, label='Varying $b_{3}$')
plt.plot(Q2, mean_b4, label='Varying $b_{4}$')
plt.legend()

# %%
plt.plot(Q2, b1_ratio_new, label='b1 ratio', color='blue')

# %%
print(b1_ratio_new)
print(b_ratio_new)
# Out:
# [0.         0.99487695 1.00367703 1.0134517  1.02357801 1.03428916
#  1.04543073 1.05735797 1.06968926 1.08313613 1.09654984 1.1116892
#  1.12428093 1.13895803 1.15570635 1.17143022 1.19021832 1.20373135
#  1.22353469 1.24160493 1.25926383 1.2813113  1.29798049 1.32308575
#  1.34195658 1.35568246 1.38212358 1.41116274 1.41690252 1.44887378
#  1.48528057 1.55558094 1.51863471 1.54535349 1.55977113]
# [ 0.          0.28979762  0.39159511  0.51244892  0.66418948  0.83647454
#   1.0964318   1.36821469  1.85769071  2.24601997  2.796758    3.47721765
#   4.22067113  4.76308366  6.00642956  6.32329192  7.55555282  9.42390646
#   9.70205948 10.7792727  13.04401949 13.76913489 17.71631968 19.27622195
#  20.92866063 27.0666508  31.07692658 33.88137091 33.16181469 53.2708439
#  57.37731951 57.38257412 74.61117693 71.02400267 87.74566755]

# %%
plt.plot(Q2, b4_ratio, color='pink', label='new basis')
plt.plot(Q2, b_ratio_new , color='red')

# %%
print(a1_ratio)
print(b_ratio_new)
# Out:
# [0.         0.96743393 0.90981695 0.85221004 0.79982744 0.75212049
#  0.71090209 0.67517039 0.64818552 0.62679612 0.61663077 0.61273196
#  0.62635215 0.64625256 0.67188962 0.71430417 0.75888472 0.82810633
#  0.90201894 0.98305285 1.07934132 1.18481671 1.30588809 1.42701908
#  1.55737946 1.78057647 1.92384704 2.06688684 2.33989841 2.52731659
#  2.76728392 2.7795456  3.31051041 3.5839011  3.94650804]
# [ 0.          0.28979762  0.39159511  0.51244892  0.66418948  0.83647454
#   1.0964318   1.36821469  1.85769071  2.24601997  2.796758    3.47721765
#  -0.12622953 ,-0.11639963, -0.10731903 ,-0.09891832, -0.09113583, -0.08391664,
#  -0.0772117  ,-0.07097709, -0.06517339, -0.05976516, -0.05472043, -0.05001033,
#  -0.04560872, -0.04149191, -0.03763838, -0.03402852, -0.03064447, -0.02746994,
#  -0.02449001, -0.02169102, -0.01906046, -0.01658682, -0.01425954, -0.01206886,
#  -0.01000583, -0.00806216])

# %% [markdown]
#  #gStyle->SetOptStat(0);
#    auto C  = new TCanvas("C", "A ratio example");
#    auto h1 = new TH1D("h1", "TRatioPlot Example; x; y", 50, 0, 10);
#    auto h2 = new TH1D("h2", "h2", 50, 0, 10);
#    auto f1 = new TF1("f1", "exp(- x/[0] )");
#    f1->SetParameter(0, 3);
#    h1->FillRandom("f1", 1900);
#    h2->FillRandom("f1", 2000);
#    h1->Sumw2();
#    h2->Scale(1.9 / 2.);
#    h2->SetLineColor(kRed);
#
#    // Create and draw the ratio plot
#    auto rp = new TRatioPlot(h1, h2);
#    C->SetTicks(0, 1);
#    rp->Draw();
#    rp->GetLowYaxis()->SetNdivisions(505);
#
#    // Add a legend to the ratio plot
#    rp->GetUpperPad()->cd();
#    TLegend *legend = new TLegend(0.3,0.7,0.7,0.85);
#    legend->AddEntry("h1","First histogram","l");
#    legend->AddEntry("h2","Second histogram","le");
#    legend->Draw();

# %%
#include <iostream>
ROOT.gStyle.SetOptStat(0)
C1  = ROOT.TCanvas("C1", "A ratio example");

#h1 = ROOT.TH1D("h1", "TRatioPlot Example; x; y", 50, 0, 8);
h1 = myFilehists.mystatshisto
h2 = myFilehists.Q2histrw
h1.SetLineColor(ROOT.kBlue)
h2.SetLineColor(ROOT.kRed)
h1.Draw("CHIST")
h1.GetXaxis().SetTitle("Energy (GeV)")
h1.GetYaxis().SetTitle("Counts")

histo_a1.Draw('CHIST')
histo_acv.Draw('CHIST')

#Create and draw the ratio plot
rp = ROOT.TRatioPlot(h1, h2);
C1.SetTicks(0, 1);
rp.Draw();
#rp.GetXaxis().SetTitle("Energy (GeV)")

rp.GetXaxis().SetRangeUser(0, 5);

#rp.GetLowerPad().SetRangeUser(0,1);

rp.GetLowYaxis().SetNdivisions(505);

#Add a legend to the ratio plot

rp.GetUpperPad().cd();
rp.GetLowerRefYaxis().SetTitle("Ratio");
legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry("h1","(b params)  GENIE", "l");
legend.AddEntry("h2","a_{cv} using GENIE","l");
#legend.AddEntry("rplot2","a_{1}+ #sigma cov mat","l")
legend.Draw();
rp.GetLowerRefGraph().SetMinimum(0);
rp.GetLowerRefGraph().SetMaximum(1);
rp.GetLowerRefGraph().SetTitle("Energy (GeV)")

#rp.GetXaxis().SetRangeUser(0, 5)
#rp.Draw()
C1.Update()
C1.Draw()
# Out:
# Info in <TROOT::TEfficiency::CheckBinning>: Histograms are not consistent: they have different number of bins
# Error in <TGraphAsymmErrors::Divide>: passed histograms are not consistent
# <div id="root_plot_1693342155753"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1693342155753(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.875000065192584,"fY1":-2842.47378303023,"fX2":7.87500006519259,"fY2":25582.2623530257,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":79.5428559575761,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.0166052552868303,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.875000065192584,"fPixeltoXk":-0.875000065192584,"fPixeltoX":0.0125718392677948,"fAbsPixeltoYk":25582.2623530257,"fPixeltoYk":-2842.47378303023,"fPixeltoY":-60.2218985933389,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":7,"fUymax":22739.7885699955,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":1,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":7,"fY2":22739.7885699955,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":8,"fName":"Q2histrw","fTitle":"q2","fLineColor":632,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":37,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"Q^{2}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":35,"fXmin":0,"fXmax":7,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"Count","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":100000,"fTsumw":100818.751409533,"fTsumw2":101774.016737843,"fTsumwx":71660.0303574742,"fTsumwx2":105773.984760172,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":{"$arr":"Float64","len":37,"p":1,"v":[21851.7622957546,20911.2120712863,16014.4046004836,11751.5661594606,8484.10297223435,5941.25456069166,4342.68659866385,2968.74763355022,2241.54294828139,1608.8131377948,1144.58699367344,883.694403778998,711.47999971817,517.858047911557,453.629958367177,343.498240564438,255.812237327869,233.363885580399,199.825016356886,157.859753671006,131.470292587779,97.8330590956946,90.6886982468144,81.4942091901077,59.130505188122,48.9375183704616,44.9162610244164,45.8427497722 ...

# %%
c912 = ROOT.TCanvas()


histo_a1_plus_1sigma = myFilehists.Q2histrwa1
histo_a1_minus_1sigma = myFilehists.Q2histrwa1minus
histo_cv_reweight = myFilehists.Q2histrw

pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

histo_a1_minus_1sigma.Draw("CHIST")
histo_a1_plus_1sigma.Draw("SAME CHIST")

pad1.Update()


legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(histo_a1_plus_1sigma,"F_{A}(a_{1}+ #sigma)  GENIE", 'l');
legend.AddEntry(histo_a1_minus_1sigma,"F_{A}(a_{1}- #sigma)  GENIE", 'l');
legend.Draw()

c912.cd()

pad2 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad2.SetGridx()
pad2.Draw()
pad2.cd()


h3 = histo_a1_minus_1sigma.Clone("h3");
h3.Divide(histo_cv_reweight)
h3.SetLineColor(ROOT.kBlack);
h3.Draw();       #// Draw the ratio plot


pad2.Update();
legend.AddEntry(histo_a1_plus_1sigma,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
legend.AddEntry(histo_a1_minus_1sigma,"F_{A}(a_{1} - #sigma)/ F_{A}(a_{cv}) GENIE", 'l');

c912.cd();
legend.DrawClone("same");

c912.Draw()
# Out:
# <div id="root_plot_1693342160094"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1693342160094(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":696,"fYtoAbsPixelk":472.00005,"fYtoPixelk":472.00005,"fYtoPixel":-472,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.0014367816091954,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00211864406779661,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.875000065192584,"fY1":0,"fX2":7.87500006519259,"fY2":26083.5067137544,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":79.5428559575761,"fYtoAbsPixelk":330.40005,"fYtoPixelk":330.40005,"fYtoPixel":-0.0126670084519645,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":330.40005,"fVtoPixelk":330.4,"fVtoPixel":-330.4,"fAbsPixeltoXk":-0.875000065192584,"fPixeltoXk":-0.875000065192584,"fPixeltoX":0.0125718392677948,"fAbsPixeltoYk":26083.5067137544,"fPixeltoYk":0,"fPixeltoY":-78.9452382377555,"fXlowNDC":0,"fYlowNDC":0.3,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":0.7,"fAbsXlowNDC":0,"fAbsYlowNDC":0.3,"fAbsWNDC":1,"fAbsHNDC":0.7,"fUxmin":0,"fUymin":0,"fUxmax":7,"fUymax":23475.1559452103,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":7,"fY2":23475.1559452103,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":8,"fName":"Q2histrwa1minus","fTitle":"q2","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":37,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"Q^{2}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":35,"fXmin":0,"fXmax":7,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"Count","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":
fractional_error_a4_minus= [1.0, 0.9838664622445622, 0.9794007489936835, 0.9754320850069276, 0.9711746649502969, 0.9668419636197495, 0.9626537129566494, 0.9587447216080185, 0.9551850635384304, 0.9520048002622089, 0.9492108501248923, 0.9467972941869353, 0.9447514690833198, 0.9430575244611236, 0.9416984799832925, 0.9406573959815793, 0.9399180193836048, 0.9394651186462804, 0.9392846349364558, 0.939363725876045, 0.9396907478931996, 0.9402552050360847, 0.9410476810795024, 0.942059765016504, 0.9432839758865522, 0.9447136903406381, 0.9463430747737589, 0.9481670228948318, 0.9501810990247972, 0.952381487072644, 0.9547649449473435, 0.957328764064762, 0.9600707335669015, 0.962989108863914, 0.9660825841223608, 0.9693502683478632, 0.9727916647403402, 0.9764066530321917, 0.9801954745520186, 0.9841587197875022, 0.9882973182503401, 0.9926125304733917, 0.9971059419948872, 1.0017794592081046, 1.0066353069754839, 1.0116760279262027, 1.0169044833734633, 1.0223238558053078, 1.0279376529179498, 1.0337497131756548]




Q2 = [0.0, 0.10204081632653061, 0.20408163265306123, 0.30612244897959184, 0.40816326530612246, 0.5102040816326531, 0.6122448979591837, 0.7142857142857143, 0.8163265306122449, 0.9183673469387755, 1.0204081632653061, 1.1224489795918369, 1.2244897959183674, 1.3265306122448979, 1.4285714285714286, 1.5306122448979593, 1.6326530612244898, 1.7346938775510203, 1.836734693877551, 1.9387755102040818, 2.0408163265306123, 2.142857142857143, 2.2448979591836737, 2.3469387755102042, 2.4489795918367347, 2.5510204081632653, 2.6530612244897958, 2.7551020408163267, 2.857142857142857, 2.9591836734693877, 3.0612244897959187, 3.163265306122449, 3.2653061224489797, 3.36734693877551, 3.4693877551020407, 3.5714285714285716, 3.673469387755102, 3.7755102040816326, 3.8775510204081636, 3.979591836734694, 4.081632653061225, 4.183673469387755, 4.285714285714286, 4.387755102040816, 4.4897959183673475, 4.591836734693878, 4.6938775510204085, 4.795918367346939, 4.8979591836734695, 5.0]

# %%
histo_a1.SetTitle('')
histo_a1.SetMarkerColor(ROOT.kBlack)

histo_a1.SetXTitle('Q^{2} (GeV)')

# %%
h1 = histo_altogether
h2 = histo_acv
#h1_minus = histo_stats_newbasis


canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

h1.SetStats(0);  
h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l")
#h1_minus.DrawCopy("same l")


h2.Draw("same l")

h2.SetTitle("Comparing the Axial Form factor using GENIE new basis")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(a_{1}+ #sigma)  GENIE", 'l');
#legend.AddEntry(h1_minus,"F_{A}(a_{1}- #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


#h3_minus = h1_minus.Clone("h3_minus");
#h3_minus.Divide(h2)
#h3_minus.SetLineColor(ROOT.kBlack);
#h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");
h3_minus.GetYaxis().SetRangeUser(0,11);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");
h3_minus.GetYaxis().SetRangeUser(0,3);
h3_minus.GetXaxis().SetRangeUser(0,3);
h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(a_{1} #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

#canvas.SaveAs("filename.svg","SVG")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 61
#      56 h3.Draw('samel ');       #// Draw the ratio plot
#      59 pad2.Update();
# ---> 61 h3_minus.GetYaxis().SetTitle("Ratio");
#      62 h3_minus.GetYaxis().SetRangeUser(0,11);
#      63 h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");
#
# NameError: name 'h3_minus' is not defined
# Error in <TH1D::Divide>: Cannot divide histograms with different number of bins

# %%
#histograms = [histo_b1,histo_b2,histo_b3, histo_b4,histo_b1_minus,histo_b2_minus,histo_b3_minus,histo_b4_minus]

#for v in values:

h1 = histo_altogether
h2 = histo_acv
h1_minus = histo_altogether_minus


canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

h1.SetStats(0);  
h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l")
h1_minus.DrawCopy("same l")


h2.Draw("same l")

h2.SetTitle("Comparing the Axial Form factor using GENIE")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(a_{1}+ #sigma,a_{2}+ #sigma,a_{3}+ #sigma,a_{4}+ #sigma)  GENIE", 'l');
legend.AddEntry(h1_minus,"F_{A}(a_{1}-#sigma,a_{2}- #sigma,a_{3}- #sigma,a_{4}- #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


h3_minus = h1_minus.Clone("h3_minus");
h3_minus.Divide(h2)
h3_minus.SetLineColor(ROOT.kBlack);
h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");
h3_minus.GetYaxis().SetRangeUser(0.5,1.5);
h3_minus.GetXaxis().SetRangeUser(0,5);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");

h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(a_{1}-#sigma,a_{2}- #sigma,a_{3}- #sigma,a_{4}- #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

canvas.SaveAs("b1_histo.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file b1_histo.pdf has been created
# <div id="root_plot_1693342257044"
#      style="width: 750px; height: 750px">
# </div>
# <script>
#
# function display_root_plot_1693342257044(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":750,"fYtoAbsPixelk":750.00005,"fYtoPixelk":750.00005,"fYtoPixel":-750,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":750,"fVtoAbsPixelk":750.00005,"fVtoPixelk":750,"fVtoPixel":-750,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00133333333333333,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00133333333333333,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.875000065192584,"fY1":0,"fX2":7.87500006519259,"fY2":24348.1683532738,"fXtoAbsPixelk":75.0000544703486,"fXtoPixelk":75.0000544703486,"fXtoPixel":85.7142844370433,"fYtoAbsPixelk":525.00005,"fYtoPixelk":525.00005,"fYtoPixel":-0.0215621968922935,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":750,"fVtoAbsPixelk":525.00005,"fVtoPixelk":525,"fVtoPixel":-525,"fAbsPixeltoXk":-0.875000065192584,"fPixeltoXk":-0.875000065192584,"fPixeltoX":0.0116666668405136,"fAbsPixeltoYk":24348.1683532738,"fPixeltoYk":0,"fPixeltoY":-46.3774635300453,"fXlowNDC":0,"fYlowNDC":0.3,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":0.7,"fAbsXlowNDC":0,"fAbsYlowNDC":0.3,"fAbsWNDC":1,"fAbsHNDC":0.7,"fUxmin":0,"fUymin":0,"fUxmax":7,"fUymax":21913.3514272424,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":7,"fY2":21913.3514272424,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":521,"fName":"Q2histrwaltogether_copy","fTitle":"q2","fLineColor":600,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":37,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"Q^{2}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":35,"fXmin":0,"fXmax":7,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"Count","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFon ...

# %%
#histograms = [histo_b1,histo_b2,histo_b3, histo_b4,histo_b1_minus,histo_b2_minus,histo_b3_minus,histo_b4_minus]

#for v in values:

h1 = histo_b2
h2 = histo_acv
h1_minus = histo_b2_minus


canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

h1.SetStats(0);  
h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l")
h1_minus.DrawCopy("same l")


h2.Draw("same l")

h2.SetTitle("Comparing the Axial Form factor using GENIE")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(b_{2}+ #sigma)  GENIE", 'l');
legend.AddEntry(h1_minus,"F_{A}(b_{2}- #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


h3_minus = h1_minus.Clone("h3_minus");
h3_minus.Divide(h2)
h3_minus.SetLineColor(ROOT.kBlack);
h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");
h3_minus.GetYaxis().SetRangeUser(0.5,1.5);
h3_minus.GetXaxis().SetRangeUser(0,5);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");

h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(b_{2} #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

canvas.SaveAs("b2_histo.pdf")

# %%
#histograms = [histo_b1,histo_b2,histo_b3, histo_b4,histo_b1_minus,histo_b2_minus,histo_b3_minus,histo_b4_minus]

#for v in values:

h1 = histo_b3
h2 = histo_acv
h1_minus = histo_b3_minus


canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

h1.SetStats(0);  
h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l")
h1_minus.DrawCopy("same l")


h2.Draw("same l")

h2.SetTitle("Comparing the Axial Form factor using GENIE")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(b_{3}+ #sigma)  GENIE", 'l');
legend.AddEntry(h1_minus,"F_{A}(b_{3}- #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


h3_minus = h1_minus.Clone("h3_minus");
h3_minus.Divide(h2)
h3_minus.SetLineColor(ROOT.kBlack);
h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");
h3_minus.GetYaxis().SetRangeUser(0.5,1.5);
h3_minus.GetXaxis().SetRangeUser(0,5);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");

h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(b_{3} #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

canvas.SaveAs("b3_histo.pdf")

# %%
#histograms = [histo_b1,histo_b2,histo_b3, histo_b4,histo_b1_minus,histo_b2_minus,histo_b3_minus,histo_b4_minus]

#for v in values:

h1 = histo_b4
h2 = histo_acv
h1_minus = histo_b4_minus


canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

h1.SetStats(0);  
h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l")
h1_minus.DrawCopy("same l")


h2.Draw("same l")

h2.SetTitle("Comparing the Axial Form factor using GENIE")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(b_{4}+ #sigma)  GENIE", 'l');
legend.AddEntry(h1_minus,"F_{A}(b_{4}- #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


h3_minus = h1_minus.Clone("h3_minus");
h3_minus.Divide(h2)
h3_minus.SetLineColor(ROOT.kBlack);
h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");
h3_minus.GetYaxis().SetRangeUser(0.5,1.5);
h3_minus.GetXaxis().SetRangeUser(0,5);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");

h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(b_{4} #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

canvas.SaveAs("b4_histo.pdf")

# %%
histo_stats_newbasis.Draw()

# %%
#histograms = [histo_b1,histo_b2,histo_b3, histo_b4,histo_b1_minus,histo_b2_minus,histo_b3_minus,histo_b4_minus]

#for v in values:

h1 = histo_stats_newbasis
h2 = histo_acv
h1_minus = histo_b3_minus


canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

h1.SetStats(0);  
h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l")
h1_minus.DrawCopy("same l")


h2.Draw("same l")

h2.SetTitle("Comparing the Axial Form factor using GENIE")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(b_{3}+ #sigma)  GENIE", 'l');
legend.AddEntry(h1_minus,"F_{A}(b_{3}- #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


h3_minus = h1_minus.Clone("h3_minus");
h3_minus.Divide(h2)
h3_minus.SetLineColor(ROOT.kBlack);
h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");
h3_minus.GetYaxis().SetRangeUser(0.5,1.5);
h3_minus.GetXaxis().SetRangeUser(0,5);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");

h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(b_{3} #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

canvas.SaveAs("b3_histo.pdf")

# %%
h1 = histo_a3
h2 = histo_acv
h1_minus = histo_a3_minus


canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

h1.SetStats(0);  
h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l")
h1_minus.DrawCopy("same l")


h2.Draw("same l")

h2.SetTitle("Comparing the Axial Form factor using GENIE")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(a_{3}+ #sigma)  GENIE", 'l');
legend.AddEntry(h1_minus,"F_{A}(a_{3}- #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


h3_minus = h1_minus.Clone("h3_minus");
h3_minus.Divide(h2)
h3_minus.SetLineColor(ROOT.kBlack);
h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");
h3_minus.GetYaxis().SetRangeUser(0,10);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");

h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(a_{3} #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

# %%
h1 = histo_a4
h2 = histo_acv
h1_minus = histo_a4_minus


canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

h1.SetStats(0);  
h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l")
h1_minus.DrawCopy("same l")


h2.Draw("same l")

h2.SetTitle("Comparing the Axial Form factor using GENIE")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(a_{4}+ #sigma)  GENIE", 'l');
legend.AddEntry(h1_minus,"F_{A}(a_{4}- #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


h3_minus = h1_minus.Clone("h3_minus");
h3_minus.Divide(h2)
h3_minus.SetLineColor(ROOT.kBlack);
h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");
h3_minus.GetYaxis().SetRangeUser(0.8,1.15);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");

h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(a_{4} #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

# %%
h1 = histo_altogether
h2 = histo_acv
h1_minus = histo_altogether_minus


canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

h1.SetStats(0);  
h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l")
h1_minus.DrawCopy("same l")


h2.Draw("same l")

h2.SetTitle("Comparing the Axial Form factor using GENIE")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(a_{i}+ #sigma)  GENIE", 'l');
legend.AddEntry(h1_minus,"F_{A}(a_{i}- #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


h3_minus = h1_minus.Clone("h3_minus");
h3_minus.Divide(h2)
h3_minus.SetLineColor(ROOT.kBlack);
h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");
h3_minus.GetYaxis().SetRangeUser(0,1.5);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV^{2})");

h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(a_{i} #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

# %%
 #TH1F *h1 = new TH1F("h1", "Two gaussian plots and their ratio;x title; h1 and h2 gaussian histograms", 100, -5, 5);
  # TH1F *h2 = new TH1F("h2", "h2", 100, -5, 5);
#h1->FillRandom("gaus");
#h2->FillRandom("gaus");
h1 = histo_a1
h2 = histo_acv
   #// Define the Canvas
#TCanvas *c = new TCanvas("c", "canvas", 800, 800);
canvas = ROOT.TCanvas()

  # // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
   #TPad *pad1 = new TPad("pad1", "pad1", 0, 0.3, 1, 1.0);
pad1.SetBottomMargin(0)

   #pad1->SetBottomMargin(0); // Upper and lower plot are joined
  # pad1->SetGridx();         // Vertical grid
pad1.SetGridx()

   #pad1->Draw();             // Draw the upper pad: pad1
pad1.Draw()
 #  pad1->cd();               // pad1 becomes the current pad
pad1.cd()
 #  h1->SetStats(0);          // No statistics on upper plot
h1.SetStats(0);  
   #h1->Draw();               // Draw h1
h1.SetLabelColor(ROOT.kBlue)
h1.SetLineColor(ROOT.kBlue)
h1.Draw("CHIST l")
  # h2->Draw("same");         // Draw h2 on top of h1
h2.Draw("same CHIST l")


graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a4)));
graph3.SetLineColor(ROOT.kGreen+3)
graph3.Scale(h2[1])
graph3.Draw("same ");
pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(a_{4}+ #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');
legend.AddEntry(graph3,"F_{A}(a_{4}+ #sigma) thrown", 'l');
 
#if ROOT_VERSION_CODE >= ROOT_VERSION(6,8,0)
#// Avoid the first label (0) to be clipped.
   #TAxis *axis = h1->GetYaxis();
   #axis->ChangeLabel(1, -1, -1, -1, -1, -1, " ");
   #axis->SetLabelFont(43); // Absolute font size in pixel (precision 3)
   #axis->SetLabelSize(15);
#else
   #// Do not draw the Y axis label on the upper plot and redraw a small
   #// axis instead, in order to avoid the first label (0) to be clipped.
   #h1->GetYaxis()->SetLabelSize(0.);
   #TGaxis *axis = new TGaxis( -5, 20, -5, 220, 20,220,510,"");
  # axis->SetLabelFont(43); // Absolute font size in pixel (precision 3)
  # axis->SetLabelSize(15);
  # axis->Draw();
#endif
 
  # // lower plot will be in pad
   #c->cd();          // Go back to the main canvas before defining pad2
canvas.cd()
   #TPad *pad2 = new TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
   #pad2->SetTopMargin(0);
pad2.SetTopMargin(0)
   #pad2->SetBottomMargin(0.2);
pad2.SetBottomMargin(0.2);
   #pad2->SetGridx(); // vertical grid\
pad2.SetGridx()
   #pad2->Draw();
pad2.Draw()
   #pad2->cd();       // pad2 becomes the current pad
pad2.cd()


 #// Define the ratio plot
#TH1F *h3 = (TH1F*)h1->Clone("h3");

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineColor(ROOT.kBlack);
#h3.SetMinimum(-1);  #// Define Y ..
#h3.SetMaximum(1); #// .. range
   #h3->Sumw2();
   #h3->SetStats(0);      // No statistics on lower plot
   #h3->Divide(h2);
   #h3->SetMarkerStyle(21);
h3.Draw();       #// Draw the ratio plot

h3.GetYaxis().SetTitle("Ratio");
h3.GetYaxis().SetRangeUser(-2,4);

h3.GetXaxis().SetRangeUser(0,5);
h3.GetYaxis().SetNdivisions(505);
h3.GetYaxis().SetTitleSize(12);
h3.GetXaxis().SetTitle("Energy (GeV)");
h3.GetXaxis().SetTitleSize(12);
h3.GetYaxis().SetLabelSize(12);
h3.GetXaxis().SetLabelSize(12);
h3.GetXaxis().SetLabelColor(ROOT.kBlack);


graph = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(1,fractional_error_a4)));
graph.SetLineColor(ROOT.kMagenta)
graph.Draw("same  l");
pad2.Update();
graph2 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(1,fractional_error_a4_minus)));
graph2.SetLineColor(ROOT.kMagenta)
graph2.Draw("same l ");





pad2.Update();
legend.AddEntry(graph,"F_{A}(a_{4} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(a_{4} + #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
#legend.AddEntry("rplot2","a_{1}+ #sigma cov mat","l")
canvas.cd();
legend.DrawClone("same");
canvas.Draw()

# %%
 #TH1F *h1 = new TH1F("h1", "Two gaussian plots and their ratio;x title; h1 and h2 gaussian histograms", 100, -5, 5);
  # TH1F *h2 = new TH1F("h2", "h2", 100, -5, 5);
#h1->FillRandom("gaus");
#h2->FillRandom("gaus");


FA_plus_i = [1.2723, 1.0386970404194165, 0.8585614585140573, 0.7204952692887494, 0.6129462138514445, 0.5276134289841838, 0.45874897143048454, 0.4023371069653613, 0.35551869462819496, 0.3162162075033531, 0.2828905636898509, 0.25438122052610385, 0.22979898884792554, 0.20845273492778765, 0.18979828095933268, 0.17340213387970588, 0.15891530832864476, 0.14605414437122996, 0.13458605312147598, 0.12431878766865281, 0.11509227180213534, 0.10677230892370808, 0.09924568981294157, 0.09241635281678243, 0.08620234406952945, 0.08053339176068967, 0.07534895594803687, 0.07059664974863618, 0.06623095283764774, 0.06221215671390405, 0.058505495000665805, 0.055080422433208015, 0.05191001405725752, 0.048970462177983475, 0.0462406532303082, 0.04370181033150889, 0.04133719007888616, 0.03913182435559911, 0.03707229964609512, 0.03514656774370165, 0.03334378283625113, 0.031654160841511784, 0.03006885757903626, 0.028579862944569646, 0.027179908725091254, 0.025862388078537295, 0.02462128501922373, 0.02345111251131463, 0.022346857988959416, 0.021303935301355586, 4.501540236726174e-17, 0.061892737852740826, 0.07549149596778622, 0.07563580146968686, 0.07172876928281227, 0.06686368213261377, 0.062125892352771356, 0.05787238642908659, 0.05417944022451799, 0.051015908909577225, 0.04831435941435237, 0.04600079156583479, 0.04400658162856229, 0.04227256059139951, 0.040749626478490474, 0.039397916835335826, 0.038185486854109406, 0.03708692572370304, 0.036082094899328246, 0.03515505137363865, 0.0342931624898706, 0.03348639455331641, 0.03272674921963149, 0.03200782095870357, 0.03132445148278366, 0.03067246071412039, 0.030048437615365565, 0.0294495775724831, 0.028873555859974934, 0.02831842902876238, 0.02778255789482848, 0.027264547247454543, 0.026763198514835364, 0.026277472488767696, 0.025806459874746675, 0.025349357944193775, 0.0249054519572368, 0.024474100325150898, 0.024054722712619873, 0.02364679045776906, 0.023249818824982702, 0.022863360711399015, 0.02248700150995448, 0.02212035489547481, 0.02176305934981421, 0.02141477528066055, 0.021075182618824122, 0.02074397880250674, 0.020420877075663337, 0.020105605042238857]
FA_minus_i = [1.2723, 0.9759450406537086, 0.781777877988664, 0.6433966918688887, 0.5397212103869419, 0.4592931184499961, 0.3952453150728028, 0.34318605388383516, 0.300168533520226, 0.26413928406138865, 0.2336222028032879, 0.20752802320305422, 0.1850346370460752, 0.16550935045404452, 0.14845690970742004, 0.13348386610089283, 0.12027358185262524, 0.10856833291640419, 0.09815624861431319, 0.08886161458654551, 0.08053755867187895, 0.07306045488390447, 0.0663255864204835, 0.060243745243362026, 0.05473853800959971, 0.0497442314647422, 0.045204014579277634, 0.04106858599044387, 0.03729499778385938, 0.03384570301387442, 0.0306877664297221, 0.027792206879537314, 0.02513344665703964, 0.022688848231268946, 0.02043832277983287, 0.018363998033017272, 0.016449935349162198, 0.01468188784175872, 0.013047092884950907, 0.011534093525634795, 0.010132584294389901, 0.008833277685206121, 0.00762778820459354, 0.006508531404476995, 0.0054686357338009535, 0.004501865389423827, 0.0036025526321478048, 0.002765538270059431, 0.001986119207872457, 0.0012600021249346942]

h1 = histo_a1
h2 = histo_acv
   #// Define the Canvas
#TCanvas *c = new TCanvas("c", "canvas", 800, 800);
canvas = ROOT.TCanvas()

  # // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
   #TPad *pad1 = new TPad("pad1", "pad1", 0, 0.3, 1, 1.0);
pad1.SetBottomMargin(0)

   #pad1->SetBottomMargin(0); // Upper and lower plot are joined
  # pad1->SetGridx();         // Vertical grid
pad1.SetGridx()

   #pad1->Draw();             // Draw the upper pad: pad1
pad1.Draw()
 #  pad1->cd();               // pad1 becomes the current pad
pad1.cd()
 #  h1->SetStats(0);          // No statistics on upper plot
h1.SetStats(0);  
   #h1->Draw();               // Draw h1
h1.SetLabelColor(ROOT.kBlue)
h1.SetLineColor(ROOT.kBlue)
h1.Draw("CHIST l")
  # h2->Draw("same");         // Draw h2 on top of h1
h2.Draw("same CHIST l")


graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_i)));
graph3.SetLineColor(ROOT.kGreen+3)
graph3.Scale(h2[1])
graph3.Draw("same ");
pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"F_{A}(a_{i}+ #sigma)  GENIE", 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');
legend.AddEntry(graph3,"F_{A}(a_{i}+ #sigma) thrown", 'l');
 
#if ROOT_VERSION_CODE >= ROOT_VERSION(6,8,0)
#// Avoid the first label (0) to be clipped.
   #TAxis *axis = h1->GetYaxis();
   #axis->ChangeLabel(1, -1, -1, -1, -1, -1, " ");
   #axis->SetLabelFont(43); // Absolute font size in pixel (precision 3)
   #axis->SetLabelSize(15);
#else
   #// Do not draw the Y axis label on the upper plot and redraw a small
   #// axis instead, in order to avoid the first label (0) to be clipped.
   #h1->GetYaxis()->SetLabelSize(0.);
   #TGaxis *axis = new TGaxis( -5, 20, -5, 220, 20,220,510,"");
  # axis->SetLabelFont(43); // Absolute font size in pixel (precision 3)
  # axis->SetLabelSize(15);
  # axis->Draw();
#endif
 
  # // lower plot will be in pad
   #c->cd();          // Go back to the main canvas before defining pad2
canvas.cd()
   #TPad *pad2 = new TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
   #pad2->SetTopMargin(0);
pad2.SetTopMargin(0)
   #pad2->SetBottomMargin(0.2);
pad2.SetBottomMargin(0.2);
   #pad2->SetGridx(); // vertical grid\
pad2.SetGridx()
   #pad2->Draw();
pad2.Draw()
   #pad2->cd();       // pad2 becomes the current pad
pad2.cd()


 #// Define the ratio plot
#TH1F *h3 = (TH1F*)h1->Clone("h3");

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineColor(ROOT.kBlack);
#h3.SetMinimum(-1);  #// Define Y ..
#h3.SetMaximum(1); #// .. range
   #h3->Sumw2();
   #h3->SetStats(0);      // No statistics on lower plot
   #h3->Divide(h2);
   #h3->SetMarkerStyle(21);
h3.Draw();       #// Draw the ratio plot

h3.GetYaxis().SetTitle("Ratio");
h3.GetYaxis().SetRangeUser(-2,4);

h3.GetXaxis().SetRangeUser(0,5);
h3.GetYaxis().SetNdivisions(505);
h3.GetYaxis().SetTitleSize(12);
h3.GetXaxis().SetTitle("Energy (GeV)");
h3.GetXaxis().SetTitleSize(12);
h3.GetYaxis().SetLabelSize(12);
h3.GetXaxis().SetLabelSize(12);
h3.GetXaxis().SetLabelColor(ROOT.kBlack);


graph = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(1,a_altogether_ratio)));
graph.SetLineColor(ROOT.kMagenta)
graph.Draw("same  l");
pad2.Update();
graph2 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(1,a_altogether_ratio_minus)));
graph2.SetLineColor(ROOT.kMagenta)
graph2.Draw("same l ");





pad2.Update();
legend.AddEntry(graph,"F_{A}(a_{i} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(a_{i} + #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
#legend.AddEntry("rplot2","a_{1}+ #sigma cov mat","l")
canvas.cd();
legend.DrawClone("same");
canvas.Draw()

# %%
#histograms = [histo_b1,histo_b2,histo_b3, histo_b4,histo_b1_minus,histo_b2_minus,histo_b3_minus,histo_b4_minus]

for i in range(0,len(hist_list)-1):
    
    h1 = hist_list[i]
    h2 = histo_acv
    h1_minus = hist_list[i+1]


    canvas = ROOT.TCanvas()
    canvas.SetCanvasSize(1000, 1000);
    canvas.SetWindowSize(500, 500)
    # // Upper plot will be in pad1
    pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
    pad1.SetBottomMargin(0)
    pad1.SetGridx()
    pad1.Draw()
    pad1.cd()

    h1.SetStats(0);  
    h1.SetLineColor(ROOT.kBlue)
    h1.DrawCopy("l")
    h1_minus.DrawCopy("same l")


    h2.Draw("same l")

    h2.SetTitle("Comparing the Axial Form factor using GENIE {}".format(hist_list[i]))
    #graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
    #graph3.SetLineColor(ROOT.kGreen+3)
    #graph3.Scale(h2[1])
    #graph3.Draw("same ");

    pad1.Update();

    legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
    legend.AddEntry(h1,"{}".format(hist_list[i]), 'l');
    legend.AddEntry(h1_minus,"F_{}GENIE".format(hist_list[i+1]), 'l');
    legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

    canvas.cd()
    pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
    pad2.SetTopMargin(0)
    pad2.SetBottomMargin(0.2);
    pad2.SetGridx()
    pad2.Draw()
    pad2.cd() #pad2 becomes the current pad


    h3_minus = h1_minus.Clone("h3_minus");
    h3_minus.Divide(h2)
    h3_minus.SetLineColor(ROOT.kBlack);
    h3_minus.Draw('l');

    h3 = h1.Clone("h3");
    h3.Divide(h2)
    h3.SetLineStyle(2)
    h3.SetLineWidth(2)
    h3.SetLineColor(ROOT.kBlack);
    h3.Draw('samel ');       #// Draw the ratio plot


    pad2.Update();

    h3_minus.GetYaxis().SetTitle("Ratio");
    #h3_minus.GetYaxis().SetRangeUser(0.5,1.5);
    #h3_minus.GetXaxis().SetRangeUser(0,5);
    h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");

    h3_minus.SetLineStyle(2)
    h3_minus.SetLineWidth(2)
    h3_minus.SetTitle("")
    h3_minus.GetXaxis().SetTitleSize(18);
    h3_minus.GetYaxis().SetTitleSize(18);
    h3_minus.GetYaxis().SetLabelSize(18);
    h3_minus.GetXaxis().SetLabelSize(18);
    h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
    pad2.Update();
    #legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
    #legend.AddEntry(h3,"F_{A}(b_{ #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
    canvas.cd();
    legend.DrawClone("same");
    canvas.Update();
    canvas.Draw()


    #canvas.SaveAs("{}histo.pdf".format(hist_list[i]))

# %%
hist_list[1]

# %%
h1 = myFilehists.mystatshisto
h2 = histo_acv
h1_minus = myFilehists.mystatshisto

h1.Scale(1./h1.Integral(), "width");
h2.Scale(1./h2.Integral(), "width");
h1_minus.Scale(1./h1_minus.Integral(), "width");

canvas = ROOT.TCanvas()
canvas.SetCanvasSize(1000, 1000);
canvas.SetWindowSize(500, 500)
# // Upper plot will be in pad1
pad1 = ROOT.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0)
pad1.SetGridx()
pad1.Draw()
pad1.cd()

#h1.SetStats(0);  
#h1.SetLineColor(ROOT.kBlue)
h1.DrawCopy("l e0")
h1_minus.DrawCopy("same l e0")


h2.Draw("same l e0")

h2.SetTitle("Comparing the Axial Form factor using GENIE")
#graph3 = ROOT.TGraph(50, np.array(Q2), np.array(np.multiply(-1,FA_plus_a1)));
#graph3.SetLineColor(ROOT.kGreen+3)
#graph3.Scale(h2[1])
#graph3.Draw("same ");

pad1.Update();

legend= ROOT.TLegend(0.3,0.7,0.7,0.85);
legend.AddEntry(h1,"FA {} GENIE".format(v), 'l');
legend.AddEntry(h1_minus,"F_{}GENIE".format(v), 'l');
legend.AddEntry(h2,"F_{A}(a_{cv}) GENIE", 'l');

canvas.cd()
pad2 = ROOT.TPad("pad2", "pad2", 0, 0.05, 1, 0.3);
pad2.SetTopMargin(0)
pad2.SetBottomMargin(0.2);
pad2.SetGridx()
pad2.Draw()
pad2.cd() #pad2 becomes the current pad


h3_minus = h1_minus.Clone("h3_minus");
h3_minus.Divide(h2)
h3_minus.SetLineColor(ROOT.kBlack);
h3_minus.Draw('l');

h3 = h1.Clone("h3");
h3.Divide(h2)
h3.SetLineStyle(2)
h3.SetLineWidth(2)
h3.SetLineColor(ROOT.kBlack);
h3.Draw('samel ');       #// Draw the ratio plot


pad2.Update();

h3_minus.GetYaxis().SetTitle("Ratio");

h3_minus.GetXaxis().SetRangeUser(0,5);
h3_minus.GetXaxis().SetTitle("Q^{2} (GeV)^{2}");

h3_minus.SetLineStyle(2)
h3_minus.SetLineWidth(2)
h3_minus.SetTitle("")
h3_minus.GetXaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetTitleSize(18);
h3_minus.GetYaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelSize(18);
h3_minus.GetXaxis().SetLabelColor(ROOT.kBlack);
pad2.Update();
#legend.AddEntry(graph,"F_{A}(a_{1} + #sigma)/ F_{A}(a_{cv}) thrown", 'l');
legend.AddEntry(h3,"F_{A}(b_{1} #pm #sigma)/ F_{A}(a_{cv}) GENIE", 'l');
canvas.cd();
legend.DrawClone("same");
canvas.Update();
canvas.Draw()

canvas.SaveAs("{}histo.pdf".format(v))

# %%
#myFile = ROOT.TFile.Open("myoutput_test_new.root")
#myFile = ROOT.TFile.Open("myoutput_test_new_10e5.root")
myFile= ROOT.TFile.Open("myoutput_test_new_10e5_2408_new_lowerbins.root")

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
b1 =[]
b2=[]
b3=[]
b4=[]

a1_values_for_genie_vector=[]
a2_values_for_genie_vector=[]
a3_values_for_genie_vector=[]
a4_values_for_genie_vector=[]

a1_translated_bparams = []
a2_translated_bparams = []
a3_translated_bparams = []
a4_translated_bparams = []

myTree = myFile.mytree
for entry in myTree:
    b1.append(entry.randombparameters[0])
    b2.append(entry.randombparameters[1])
    b3.append(entry.randombparameters[2])
    b4.append(entry.randombparameters[3])
    
    a1_values_for_genie_vector.append(entry.avalues_for_genie_vector[0])
    a2_values_for_genie_vector.append(entry.avalues_for_genie_vector[1])
    a3_values_for_genie_vector.append(entry.avalues_for_genie_vector[2])
    a4_values_for_genie_vector.append(entry.avalues_for_genie_vector[3])

    a1_translated_bparams.append(entry.translated_bparams[0])
    a2_translated_bparams.append(entry.translated_bparams[1])
    a3_translated_bparams.append(entry.translated_bparams[2])
    a4_translated_bparams.append(entry.translated_bparams[3])

    
    
    #print(entry.randombparameters[0])
    #y=entry.randombparameters[1]
    #print(entry.avalues_for_genie_vector)

# %%
# Fit a normal distribution to
# the data:
# mean and standard deviation
mu, std = norm.fit(b1) 
plt.hist(b1)

xmin, xmax = plt.xlim()
x = np.linspace(np.amin(b1), np.amin(b1),100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p)
title = "Fit Values: {:.2f} and {:.2f}".format(mu, std)
plt.title(title)
plt.show()

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
  
# Generate some data for this 
# demonstration.
data = np.array(b1)
  
# Fit a normal distribution to
# the data:
# mean and standard deviation
mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
title = "Histogram of $b_1$ parameters thrown from Gaussian distribution, the fit Values: {:.2f} and {:.2f}".format(mu, std)
plt.title(title)
plt.xlabel('$b_{1}$')
  
plt.show()

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
  
# Generate some data for this 
# demonstration.
data = np.array(b2)
  
# Fit a normal distribution to
# the data:
# mean and standard deviation
mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=35, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
title = "Histogram of $b_2$ parameters thrown from Gaussian distribution, the fit Values: {:.2f} and {:.2f}".format(mu, std)
plt.title(title)
plt.xlabel('$b_{2}$')
  
plt.show()

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
  
# Generate some data for this 
# demonstration.
data = np.array(b3)
  
# Fit a normal distribution to
# the data:
# mean and standard deviation
mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
title = "Histogram of $b_3$ parameters thrown from Gaussian distribution, the fit Values: {:.2f} and {:.2f}".format(mu, std)
plt.title(title)
plt.xlabel('$b_{3}$')
  
plt.show()

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
  
# Generate some data for this 
# demonstration.
data = np.array(b4)
  
# Fit a normal distribution to
# the data:
# mean and standard deviation
mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
title = "Histogram of $b_4$ parameters thrown from Gaussian distribution, the fit Values: {:.2f} and {:.2f}".format(mu, std)
plt.title(title)
plt.xlabel('$b_{4}$')
  
plt.show()

# %%
myTree.Draw('randombparameters')

# %%
a_cv = np.array([2.30 ,-0.60 ,-3.80 ,2.30])
a1_values_for_genie_vector_tr=a1_values_for_genie_vector+a_cv[0]
a2_values_for_genie_vector_tr=a2_values_for_genie_vector+a_cv[1]
a3_values_for_genie_vector_tr=a3_values_for_genie_vector+a_cv[2]
a4_values_for_genie_vector_tr=a4_values_for_genie_vector+a_cv[3]

# %%
plt.scatter( a1_values_for_genie_vector, a4_values_for_genie_vector, label ='a1 vs a4 for GENIE', color='green', alpha=0.6)

plt.scatter( a2_values_for_genie_vector, a4_values_for_genie_vector, label ='a2 vs a4 for GENIE', color='blue', alpha=0.6)
plt.scatter( a3_values_for_genie_vector, a4_values_for_genie_vector, label ='a3 vs a4 for GENIE', color='pink', alpha=0.6)
plt.scatter( a1_values_for_genie_vector, a3_values_for_genie_vector, label ='a1 vs a3 for GENIE', color='yellow', alpha=0.6)
plt.scatter( a2_values_for_genie_vector, a3_values_for_genie_vector, label ='a2 vs a3 for GENIE', color='red', alpha=0.6)
plt.scatter( a1_values_for_genie_vector, a2_values_for_genie_vector, label ='a1 vs a2 for GENIE', color='purple', alpha=0.6)



plt.legend()


plt.title('Scatter plot of scaled a parameters passed to GENIE')
# Out:
# Text(0.5, 1.0, 'Scatter plot of scaled a parameters passed to GENIE')

# %% [markdown]
# Now transform the GENIE parameters back to the originals

# %%
scaling_genie = [0.14,0.67,1,0.75]

a1_values_for_genie_vector_scaledback=np.multiply(a1_values_for_genie_vector,scaling_genie[0])
a2_values_for_genie_vector_scaledback=np.multiply(a2_values_for_genie_vector,scaling_genie[1])
a3_values_for_genie_vector_scaledback=np.multiply(a3_values_for_genie_vector,scaling_genie[2])
a4_values_for_genie_vector_scaledback=np.multiply(a4_values_for_genie_vector,scaling_genie[3])

# %%
plt.scatter( a1_values_for_genie_vector_scaledback, a4_values_for_genie_vector_scaledback, label ='a1 vs a4 for GENIE', color='green', alpha=0.6)

plt.scatter( a2_values_for_genie_vector_scaledback, a4_values_for_genie_vector_scaledback, label ='a2 vs a4 for GENIE', color='blue', alpha=0.6)
plt.scatter( a3_values_for_genie_vector_scaledback, a4_values_for_genie_vector_scaledback, label ='a3 vs a4 for GENIE', color='pink', alpha=0.6)
plt.scatter( a1_values_for_genie_vector_scaledback, a3_values_for_genie_vector_scaledback, label ='a1 vs a3 for GENIE', color='yellow', alpha=0.6)

plt.scatter( a2_values_for_genie_vector_scaledback, a3_values_for_genie_vector_scaledback, label ='a2 vs a3 for GENIE', color='red', alpha=0.6)
plt.scatter( a1_values_for_genie_vector_scaledback, a2_values_for_genie_vector_scaledback, label ='a1 vs a2 for GENIE', color='purple', alpha=0.6)
plt.legend()

# %%
plt.scatter( a1_values_for_genie_vector_tr, a4_values_for_genie_vector_tr, label ='a1 vs a4 for GENIE', color='green', alpha=0.6)

plt.scatter( a2_values_for_genie_vector_tr, a4_values_for_genie_vector_tr, label ='a2 vs a4 for GENIE', color='blue', alpha=0.6)
plt.scatter( a3_values_for_genie_vector_tr, a4_values_for_genie_vector_tr, label ='a3 vs a4 for GENIE', color='pink', alpha=0.6)
plt.scatter( a1_values_for_genie_vector_tr, a3_values_for_genie_vector_tr, label ='a1 vs a3 for GENIE', color='yellow', alpha=0.6)
plt.scatter( a1_values_for_genie_vector_tr, a2_values_for_genie_vector_tr, label ='a1 vs a2 for GENIE', color='purple', alpha=0.6)
plt.scatter( a2_values_for_genie_vector_tr, a3_values_for_genie_vector_tr, label ='a2 vs a3 for GENIE', color='red', alpha=0.6)
plt.legend()

plt.title('Scatter plot of scaled a parameters passed to GENIE')
# Out:
# Text(0.5, 1.0, 'Scatter plot of scaled a parameters passed to GENIE')

# %%
a_cv = np.array([2.30 ,-0.60 ,-3.80 ,2.30])
a1_translated_bparams_tr = a1_translated_bparams + a_cv[0]
a2_translated_bparams_tr = a2_translated_bparams + a_cv[1]
a3_translated_bparams_tr = a3_translated_bparams + a_cv[2]
a4_translated_bparams_tr = a4_translated_bparams + a_cv[3]

print(np.shape(a1_translated_bparams))
# Out:
# (100,)

# %%
plt.scatter( a3_translated_bparams_tr, a4_translated_bparams_tr, label ='a3 vs a4', color='pink', alpha=0.9)

plt.scatter( a2_translated_bparams_tr, a4_translated_bparams_tr, label ='a2 vs a4', color='blue', alpha=0.6)
plt.scatter( a1_translated_bparams_tr, a4_translated_bparams_tr, label ='a1 vs a4', color='green', alpha=0.6)
plt.scatter( a2_translated_bparams_tr, a3_translated_bparams_tr, label ='a2 vs a3', color='red', alpha=0.6)
plt.scatter( a1_translated_bparams_tr, a3_translated_bparams_tr, label ='a1 vs a3', color='orange', alpha=0.6)



plt.scatter( a1_translated_bparams_tr, a2_translated_bparams_tr, label ='a1 vs a2', color='purple', alpha=0.6)
plt.xlim(-10.5,5.5)
plt.ylim(-15,10.5)
plt.legend()
plt.title('Scatter plot of a parameters, which are translated from b parameters')
# Out:
# Text(0.5, 1.0, 'Scatter plot of a parameters, which are translated from b parameters')

# %%
plt.scatter( a1_translated_bparams, a3_translated_bparams, label ='a1 vs a3', color='yellow', alpha=0.6)

plt.scatter( a1_translated_bparams, a4_translated_bparams, label ='a1 vs a4', color='green', alpha=0.6)
plt.scatter( a2_translated_bparams, a3_translated_bparams, label ='a2 vs a3', color='red', alpha=0.6)
plt.scatter( a2_translated_bparams, a4_translated_bparams, label ='a2 vs a4', color='blue', alpha=0.6)
plt.scatter( a3_translated_bparams, a4_translated_bparams, label ='a3 vs a4', color='pink', alpha=0.2)
plt.scatter( a1_translated_bparams, a2_translated_bparams, label ='a1 vs a2', color='purple', alpha=0.6)
plt.legend()
plt.title('Scatter plot of a parameters, which are translated from b parameters')
# Out:
# Text(0.5, 1.0, 'Scatter plot of a parameters, which are translated from b parameters')

# %%
print(a1_values_for_genie_vector)
# Out:
# [-1.1239227997878714, 0.008704780185913493, -0.28130995930772834, 0.14929434940099792, 0.12437814915095761, -0.23321717498967698, -0.9837341612240043, -1.0285220496921896, 0.4038689639989736, -0.036733593771613886, -0.7469351491889809, -0.5437617067388573, 0.25621943824998916, -0.6707294345630375, -0.3461954511407129, -0.3921257030253461, 0.4415467702011313, -1.005803396066711, -1.6173261254958387, 0.9614160071765115, -1.9694721501723627, 2.9462956750648006, 1.275060745883156, 0.42141031007375, 0.9410770517351231, 0.5445554646144238, 0.07770150721781893, -0.6622951308508738, 0.12017727641517091, -0.7884771659768596, 1.7232407251243878, -0.37167975722546054, -0.03384576102452002, 0.1424101980083969, -0.8532377486117634, -1.2685796398968143, 0.9582728372780144, -1.3517229931777799, 0.2381330314303361, -3.225725801221343, -2.7574955337520666, -0.17222150766663605, -0.4616417988498345, 0.015152893977414896, -2.2980823801912442, 0.5355027363033041, 1.1976116952005726, -0.039127755054660304, 0.1881182402929593, -0.7192530834569585, 0.40224528303144974, -0.1569682671456703, -0.7225880233603496, 0.36639017307639377, -0.9273911558343704, 0.39165896473209655, -0.11978946246403628, -0.461173043798979, -0.6357348556772677, 1.013549765396951, 0.1581972117165719, -0.6589131889097198, -0.8401204575779301, -0.8092146675582221, 0.2976781654741336, 0.8953295399782186, 1.1861997197264318, 1.54398789330713, -0.632514361070411, -0.8294126223873042, 0.3556229891814486, 1.0591589313553047, 0.18780349145506858, 1.2081910581340023, 0.3775434079865478, 0.12782733322536352, 1.9964577306509066, 0.21308785011132342, 0.016754678726933495, -0.9494155504150744, -0.36638466032311956, -0.11373792391317451, -0.8555052312552542, 0.21060228262164848, -0.41283473395818426, -0.3476227007280859, -0.2596031276700005, -0.10651573731218725, 0.2935588729592069, 0.022443237635479202, -0.22094460177300101, -0.7820523859049789, -1.367616039714852, 0.7063180936557583, 0.9983812244484639, -0.2581250772201855, 1.4874403035919952, 2.8380277988169857, 0.763674345621239, 0.7587538678098105]

# %%
print(np.mean(a1_values_for_genie_vector))
print(np.mean(a2_values_for_genie_vector))
print(np.mean(a3_values_for_genie_vector))
print(np.mean(a4_values_for_genie_vector))
# Out:
# -0.05270319726683135
# 0.1575710621380961
# -0.11570437130068369
# -0.12254250713202967

# %%
print(np.std(a1_values_for_genie_vector))
print(np.std(a2_values_for_genie_vector))
print(np.std(a3_values_for_genie_vector))
print(np.std(a4_values_for_genie_vector))
# Out:
# 0.981208566895206
# 1.6035577872465805
# 2.8057538733823804
# 3.9682611094971905

# %%
print(np.std(a1_translated_bparams))
print(np.std(a2_translated_bparams))
print(np.std(a3_translated_bparams))
print(np.std(a4_translated_bparams))
# Out:
# 0.13736919936532885
# 1.074383717455209
# 2.8057538733823804
# 2.9761958321228925

# %% [markdown]
# # Comparing the Q2 dist of individual throws

# %%
c1 = ROOT.TCanvas()
hs = ROOT.THStack("hs","THStack")
bincontent_eachhisto = []
binerror_eachhisto=[]
bincenter_eachhisto=[]
histnames = []
bin_loweredge=[]
bin_upperedge=[]
alldata = []
bin_variance=[]
for i in range(0,100):
    histnames.append("hist_throw_{}".format(i))
    
    
for i in histnames:
    x = myFilehists.Get(i)
    
    x.Draw()
    hs.Add(x)
    bin_content = []
    bin_error =[]
    bin_center = []
    
    for j in range (0,35):  #loop through each bin
        bin_content.append(x.GetBinContent(j))
        bin_error.append(x.GetBinError(j))
        bin_center.append(x.GetBinCenter(j))
        bin_loweredge.append(x.GetBinLowEdge(j))
        bin_upperedge.append(x.GetBinLowEdge(j+1))
        alldata.append(x.GetBinContent(j))
    bincontent_eachhisto.append(bin_content)
    binerror_eachhisto.append(bin_error)
    bincenter_eachhisto.append(bin_center)
    bin_variance.append(np.square(x.GetBinError(j)))
hs.Draw() # Default draw stacks 'em vertically
c1.Draw("")
# Out:
# <div id="root_plot_1692832317352"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1692832317352(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.875000065192584,"fY1":-106685.691128016,"fX2":7.87500006519259,"fY2":960171.15656252,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":79.5428559575761,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-4.42421118655006e-4,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.875000065192584,"fPixeltoXk":-0.875000065192584,"fPixeltoX":0.0125718392677948,"fAbsPixeltoYk":960171.15656252,"fPixeltoYk":-106685.691128016,"fPixeltoY":-2260.28993154775,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":7,"fUymax":853485.465434504,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":7,"fY2":853485.465434504,"fBorderSize":1,"fBorderMode":0},{"_typename":"THStack","fUniqueID":0,"fBits":8,"fName":"hs","fTitle":"THStack","fHists":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH1D","fUniqueID":0,"fBits":8,"fName":"hist_throw_0","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"Q2","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0,"fXmax":7,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"count","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":100000,"fTsumw":165680.374707005,"fTsumw2":881168.231218533,"fTsumwx":264542.987382642,"fTsumwx2":856532.232592969,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2
std_acv_new =[]

for i in range(0,35):
    
    mean_acv_new.append(histo_acv_new.GetBinContent(i))
    std_acv_new.append(histo_acv_new.GetBinError(i))
    

    row_mean = np.mean(bincontent_eachhisto_array[:,i])
    row_std = np.std(bincontent_eachhisto_array[:,i])
    mean_ineachbin.append(row_mean)
    bincenter_eachbin.append(np.mean(bincenter_eachhisto_array[:,i]))
    std_ineachbin.append(row_std)
    
print(np.shape(bincenter_eachhisto_array))
print(np.shape(mean_ineachbin))
print("mean in each bin is {}".format(mean_ineachbin))




mean_acv_array=np.array(mean_acv)
std_acv_array =np.array(std_acv)
Q2_array=np.array(Q2)


#plt.semilogx()
#plt.semilogy()
#histo_acv_new
bincenter_eachhisto_array_one  = bincenter_eachhisto_array[0,:]
#plt.plot(Q2_histo, np.add(mean_altogether,sd_altogether), label='$(a_{1}+\sigma,a_{2}+\sigma,a_{3}+\sigma,a_{4}+\sigma)$')
plt.errorbar(bincenter_eachhisto_array_one, np.multiply(1,mean_ineachbin), marker='.', yerr=std_ineachbin, label='100 Throws', ls='none')
plt.errorbar(bincenter_eachhisto_array_one, mean_acv_new, yerr=std_acv_new, label='$a_{cv}$', marker='.', ls='none')
plt.legend()
plt.xlabel('$Q^{2} (GeV^{2})$')
plt.ylabel('Counts')
plt.xlim(0,7)
#plt.plot(bincenter_eachhisto_array_one, mean_ineachbin, marker='.')
# Out:
# (100, 35)
# (35,)
# mean in each bin is [0.0, 6276.130111553717, 8112.535292721265, 8128.43300413813, 7730.311720486809, 7028.173452780966, 6451.225328222182, 5884.184804518847, 5462.037649512105, 4986.536362753304, 4456.150640542555, 3942.261521757824, 3694.378360313245, 3356.564906722505, 3080.71810854965, 2841.0080669721265, 2570.6486534536702, 2387.9632773582243, 2242.836387800262, 2133.250265121775, 2040.372457620408, 1793.141962222091, 1716.9249676004056, 1731.7805756953353, 1689.8532132437526, 1585.0889259339738, 1506.187802552004, 1402.1070170592232, 1397.647444511234, 1386.0578014239209, 1160.6470752812013, 1248.438958669282, 1328.70034289609, 1086.324518136852, 1217.721918503303]
# (0.0, 7.0)

# %%
plt.hist2d(np.array(bincontent_eachhisto), bincenter_eachhisto[:,0], bins=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 plt.hist2d(np.array(bincontent_eachhisto), bincenter_eachhisto[:,0], bins=100)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
print(std_ineachbin)
print(bincontent_eachhisto_array[:,-2])
# Out:
# [0.0, 211.8837526392981, 435.2488169984219, 513.4380717050558, 554.789655880017, 565.5067594343653, 574.2275006307624, 575.1543192826304, 581.6812649189072, 578.0611855232895, 562.3581648678154, 542.5161710481235, 554.1406236546677, 550.5876687184523, 550.7505228590145, 551.3512062667781, 538.0443195492652, 536.0973038174309, 538.6525284414939, 542.5492641236152, 544.767175969818, 500.52887242170823, 497.73764981914366, 518.6379162427937, 520.3184613880699, 500.9372757201942, 485.46201609711244, 456.86491891055874, 460.9859864329215, 463.12568948719917, 389.31766806204695, 421.1805474895999, 448.68618107395395, 366.4735419631033, 411.4964014245751]
# [1230.9289961   361.66913808  416.96699509  194.12754277  363.70038538]

# %%
print(bincenter_eachhisto_array_one)
# Out:
# [-0.035  0.035  0.105  0.175  0.245  0.315  0.385  0.455  0.525  0.595
#   0.665  0.735  0.805  0.875  0.945  1.015  1.085  1.155  1.225  1.295
#   1.365  1.435  1.505  1.575  1.645  1.715  1.785  1.855  1.925  1.995
#   2.065  2.135  2.205  2.275  2.345]

# %%
plt.hist(mean_ineachbin)
# Out:
# (array([8., 7., 5., 2., 3., 1., 2., 3., 1., 3.]),
#  array([   0.        ,  810.15092949, 1620.30185899, 2430.45278848,
#         3240.60371798, 4050.75464747, 4860.90557696, 5671.05650646,
#         6481.20743595, 7291.35836545, 8101.50929494]),
#  <BarContainer object of 10 artists>)

# %%
histogram=myFilehists.hist_throw_1
q2_atbincenter = []
entry_ineachbin = []
for j in range (0,100):
    w = histogram.GetBinCenter(j)
    x2 = histogram.GetBinContent(j)
    q2_atbincenter.append(w)
    entry_ineachbin.append(x2)

print("q2_atbincenter")
print(q2_atbincenter)
print("entry_ineachbin")
print(entry_ineachbin)


#plt.hist(entry_ineachbin, nbins =100)
# Out:
# q2_atbincenter
# [-0.035, 0.035, 0.10500000000000001, 0.17500000000000002, 0.24500000000000002, 0.31500000000000006, 0.385, 0.45500000000000007, 0.525, 0.5950000000000001, 0.6650000000000001, 0.7350000000000001, 0.805, 0.8750000000000001, 0.9450000000000002, 1.0150000000000001, 1.085, 1.155, 1.225, 1.2950000000000002, 1.365, 1.435, 1.5050000000000001, 1.575, 1.645, 1.715, 1.7850000000000001, 1.8550000000000002, 1.925, 1.995, 2.0650000000000004, 2.1350000000000002, 2.2050000000000005, 2.2750000000000004, 2.345, 2.4150000000000005, 2.4850000000000003, 2.5550000000000006, 2.6250000000000004, 2.6950000000000003, 2.7650000000000006, 2.8350000000000004, 2.9050000000000002, 2.9750000000000005, 3.0450000000000004, 3.115, 3.1850000000000005, 3.2550000000000003, 3.3250000000000006, 3.3950000000000005, 3.4650000000000003, 3.5350000000000006, 3.6050000000000004, 3.6750000000000007, 3.7450000000000006, 3.8150000000000004, 3.8850000000000007, 3.9550000000000005, 4.025, 4.095000000000001, 4.165000000000001, 4.235, 4.305000000000001, 4.375000000000001, 4.445, 4.515000000000001, 4.585000000000001, 4.655, 4.7250000000000005, 4.795000000000001, 4.865, 4.9350000000000005, 5.005000000000001, 5.075000000000001, 5.1450000000000005, 5.215000000000001, 5.285000000000001, 5.355, 5.425000000000001, 5.495000000000001, 5.565, 5.635000000000001, 5.705000000000001, 5.775, 5.845000000000001, 5.915000000000001, 5.985, 6.055000000000001, 6.125000000000001, 6.195, 6.265000000000001, 6.335000000000001, 6.405000000000001, 6.4750000000000005, 6.545000000000001, 6.615000000000001, 6.6850000000000005, 6.755000000000001, 6.825000000000001, 6.8950000000000005]
# entry_ineachbin
# [0.0, 6131.195445257149, 7835.859842732307, 7810.931552524607, 7382.767168408235, 6664.794391514044, 6073.082227485027, 5497.01898988101, 5062.357961911854, 4580.267985484357, 4050.0821674491553, 3537.2838464578626, 3263.75314062555, 2908.015551469463, 2607.793008858706, 2340.9984723329776, 2053.3777543224487, 1842.0639790241255, 1661.4867551708207, 1514.183088434766, 1384.527894282304, 1158.1504477861174, 1053.831563558214, 1006.4288787002076, 929.5402227325044, 820.863694663704, 735.3900836357154, 649.4527242856735, 610.6065712983337, 569.0746953370198, 452.545762126818, 459.6380164580081, 464.71000284917113, 361.66913808440614, 385.005643106396, 357.45042908383533, 322.76824400978734, 290.2949999949137, 265.15565703738366, 251.0179675951438, 239.2598174098148, 233.44957438726266, 227.52825507856483, 235.68696330962496, 198.28371491975696, 177.27317829833126, 181.98950024734094, 162.90604670047878, 156.08887846276573, 119.31677450228753, 135.2221052371779, 144.67298991677873, 151.6257198888386, 150.0834776469448, 107.45076660148177, 118.90387938252253, 105.73298188745864, 100.97669203909312, 93.22522312764882, 99.23059494738894, 107.20744057034902, 89.63424852310365, 72.31376124409243, 61.63834673834232, 95.08264823028067, 64.36596174726185, 73.49379226390161, 87.40098704100379, 66.4701968568884, 70.31819777639913, 54.85675315256647, 51.02881868633884, 57.27694577263184, 43.52686685643224, 41.742505071236785, 52.54667627161673, 41.9351007038531, 54.7439456621128, 45.288240526028474, 75.65007969608536, 43.61889211480709, 45.88447098518531, 31.863579084258415, 25.40787706123391, 21.813531333650097, 43.43872669186214, 42.875808097064464, 59.284257293582606, 17.628456531478285, 30.44201856855602, 16.429876978749434, 37.96284257570977, 43.48721160029122, 34.46004216491323, 18.963665443750347, 27.82906656244219, 19.071984749226868, 51.88924256813653, 17.109607641264226, 29.385495437300406]

# %%
mean_bparams_hist=np.mean(mean_eachbin,axis=0)
std_bparams_hist=np.std(mean_eachbin,axis=0)

plt.plot()
plt.errorbar(q2_perbin, mean_bparams_hist, yerr=std_bparams_hist, marker='.', markersize=8,
            linestyle='none')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 mean_bparams_hist=np.mean(mean_eachbin,axis=0)
#       2 std_bparams_hist=np.std(mean_eachbin,axis=0)
#       4 plt.plot()
#
# NameError: name 'mean_eachbin' is not defined

# %%
#generate an array of normal distributed data with mean=5 and stddev=2 containing 1000 values
hnewCanvas=ROOT.TCanvas()
x = np.random.normal(5,2,1000)
w = np.ones(1000)
hnew = ROOT.TH1D("hnew","h1 title",50,0.,10.);
hnew.FillN(100, q2_atbincenter)
hnew.Draw()
hnewCanvas.Draw()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 6
#       4 w = np.ones(1000)
#       5 hnew = ROOT.TH1D("hnew","h1 title",50,0.,10.);
# ----> 6 hnew.FillN(100, q2_atbincenter)
#       7 hnew.Draw()
#       8 hnewCanvas.Draw()
#
# TypeError: none of the 2 overloaded methods succeeded. Full details:
#   void TH1::FillN(int ntimes, const double* x, const double* w, int stride = 1) =>
#     TypeError: takes at least 3 arguments (2 given)
#   void TH1::FillN(int, const double*, const double*, const double*, int) =>
#     TypeError: takes at least 5 arguments (2 given)

# %%
centers = bins[:-1] + np.diff(bins)/2 ax.hist(centers, bins=bins,
        weights=h, histtype='step')
